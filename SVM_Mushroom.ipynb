# %%
# Ravi Kiran Mahoorkar
#importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#loading dataset
df=pd.read_csv('mushroom.csv')
df
# Out:
#       Unnamed: 0 cap_shape cap_surface cap_color bruises     odor  \
# 0           1167    sunken       scaly     white      no    anise
# 1           1037    sunken     fibrous       red      no    anise
# 2            309      flat     grooves    purple     yes     foul
# 3            282      bell       scaly      pink     yes    fishy
# 4            820      flat      smooth    yellow     yes    musty
# ...          ...       ...         ...       ...     ...      ...
# 1995         863    sunken       scaly     brown     yes     foul
# 1996        1160    sunken       scaly    purple     yes    musty
# 1997         265    convex     grooves     green     yes    fishy
# 1998         411      bell      smooth     white      no  pungent
# 1999        1073    convex       scaly    yellow     yes  pungent
#
#      gill_attachment gill_spacing gill_size gill_color  ...  veil_type  \
# 0         descending      distant     broad       pink  ...    partial
# ...

# %%
#information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2000 non-null   int64
#  1   cap_shape                 2000 non-null   object
#  2   cap_surface               2000 non-null   object
#  3   cap_color                 2000 non-null   object
#  4   bruises                   2000 non-null   object
#  5   odor                      2000 non-null   object
#  6   gill_attachment           2000 non-null   object
#  7   gill_spacing              2000 non-null   object
#  8   gill_size                 2000 non-null   object
#  9   gill_color                2000 non-null   object
#  10  stalk_shape               2000 non-null   object
#  11  stalk_root                2000 non-null   object
#  12  stalk_surface_above_ring  2000 non-null   object
# ...

# %%
#describe
df.describe()
# Out:
#         Unnamed: 0  stalk_height  cap_diameter
# count  2000.000000   2000.000000   2000.000000
# mean    624.974000      8.449118     12.314345
# std     375.091938      3.697217      7.048845
# min       0.000000      2.000000      1.000000
# 25%     290.000000      5.291009      5.723521
# 50%     607.000000      8.318596     12.124902
# 75%     957.250000     11.781272     18.698605
# max    1279.000000     15.095066     25.000054

# %%
#check for na values
df.isna().sum()
# Out:
# Unnamed: 0                  0
# cap_shape                   0
# cap_surface                 0
# cap_color                   0
# bruises                     0
# odor                        0
# gill_attachment             0
# gill_spacing                0
# gill_size                   0
# gill_color                  0
# stalk_shape                 0
# stalk_root                  0
# stalk_surface_above_ring    0
# stalk_surface_below_ring    0
# stalk_color_above_ring      0
# stalk_color_below_ring      0
# veil_type                   0
# veil_color                  0
# ring_number                 0
# ring_type                   0
# spore_print_color           0
# population                  0
# habitat                     0
# class                       0
# stalk_height                0
# cap_diameter                0
# dtype: int64

# %%
#duplicates
df.duplicated().sum()
# Out:
# 1024

# %%
# Drop duplicates
#df.drop_duplicates(inplace=True)
df.shape
# Out:
# (2000, 26)

# %%
# prompt: get unique of all object columns

# Get a list of object columns
object_columns = df.select_dtypes(include=['object']).columns

# Iterate through object columns and print unique values
for col in object_columns:
    print(f"Unique values for column '{col}':")
    print(df[col].unique())
    print("-" * 20)
# Out:
# Unique values for column 'cap_shape':
# ['sunken' 'flat' 'bell' 'convex' 'conical']
# --------------------
# Unique values for column 'cap_surface':
# ['scaly' 'fibrous' 'grooves' 'smooth']
# --------------------
# Unique values for column 'cap_color':
# ['white' 'red' 'purple' 'pink' 'yellow' 'brown' 'green' 'buff' 'gray']
# --------------------
# Unique values for column 'bruises':
# ['no' 'yes']
# --------------------
# Unique values for column 'odor':
# ['anise' 'foul' 'fishy' 'musty' 'spicy' 'none' 'pungent' 'almond'
#  'creosote']
# --------------------
# Unique values for column 'gill_attachment':
# ['descending' 'notched' 'free' 'attached']
# --------------------
# Unique values for column 'gill_spacing':
# ['distant' 'crowded' 'close']
# --------------------
# Unique values for column 'gill_size':
# ['broad' 'narrow']
# --------------------
# Unique values for column 'gill_color':
# ['pink' 'chocolate' 'purple' 'orange' 'buff' 'black' 'red' 'green' 'brown'
# ...

# %%
# prompt: label encode all object columns

from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
le = LabelEncoder()

# Iterate through object columns and apply Label Encoding
for col in object_columns:
    df[col] = le.fit_transform(df[col])

# Display the first few rows of the transformed DataFrame
df.head()
# Out:
#    Unnamed: 0  cap_shape  cap_surface  cap_color  bruises  odor  \
# 0        1167          4            2          7        0     1
# 1        1037          4            0          6        0     1
# 2         309          3            1          5        1     4
# 3         282          0            2          4        1     3
# 4         820          3            3          8        1     5
#
#    gill_attachment  gill_spacing  gill_size  gill_color  ...  veil_type  \
# 0                1             2          0           7  ...          0
# 1                3             1          1           3  ...          1
# 2                1             1          0           8  ...          1
# 3                3             0          0           6  ...          0
# 4                2             1          1           6  ...          1
#
#    veil_color  ring_number  ring_type  spore_print_color  population  habitat  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2000 non-null   int64
#  1   cap_shape                 2000 non-null   int64
#  2   cap_surface               2000 non-null   int64
#  3   cap_color                 2000 non-null   int64
#  4   bruises                   2000 non-null   int64
#  5   odor                      2000 non-null   int64
#  6   gill_attachment           2000 non-null   int64
#  7   gill_spacing              2000 non-null   int64
#  8   gill_size                 2000 non-null   int64
#  9   gill_color                2000 non-null   int64
#  10  stalk_shape               2000 non-null   int64
#  11  stalk_root                2000 non-null   int64
#  12  stalk_surface_above_ring  2000 non-null   int64
#  13  stalk_surface_below_ring  2000 non-null   int64
# ...

# %%
# Drop the 'Unnamed: 0' column if it exists
if 'Unnamed: 0' in df.columns:
    df = df.drop('Unnamed: 0', axis=1)

# %%
# standardize using minmax scalar these 2 columns stalk_height	cap_diameter

from sklearn.preprocessing import MinMaxScaler

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Select the columns to standardize
columns_to_scale = ['stalk_height', 'cap_diameter']

# Fit and transform the selected columns
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# Display the first few rows of the transformed DataFrame
df
# Out:
#       cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0             4            2          7        0     1                1
# 1             4            0          6        0     1                3
# 2             3            1          5        1     4                1
# 3             0            2          4        1     3                3
# 4             3            3          8        1     5                2
# ...         ...          ...        ...      ...   ...              ...
# 1995          4            2          0        1     4                0
# 1996          4            2          5        1     5                0
# 1997          2            1          3        1     3                3
# 1998          0            3          7        0     7                2
# 1999          2            2          8        1     7                1
#
#       gill_spacing  gill_size  gill_color  stalk_shape  ...  veil_type  \
# ...

# %%
# split data fro test and train

from sklearn.model_selection import train_test_split

# Assuming 'class' is your target variable column
X = df.drop('class', axis=1)
y = df['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42) # Adjust test_size and random_state as needed

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (1340, 24)
# X_test shape: (660, 24)
# y_train shape: (1340,)
# y_test shape: (660,)

# %%
# distplot and box plot of all columns

for column in df.columns:
    plt.figure(figsize=(10, 5))  # Adjust figure size as needed

    # Distplot
    plt.subplot(1, 2, 1)
    sns.distplot(df[column])
    plt.title(f'Distribution Plot of {column}')

    # Box plot
    plt.subplot(1, 2, 2)
    sns.boxplot(y=df[column])  # Use y= for vertical box plot
    plt.title(f'Box Plot of {column}')

    plt.tight_layout()  # Adjust subplot parameters for a tight layout
    plt.show()

# %%
'''# Calculate the correlation matrix
correlation_matrix = df.corr()

# Create the heatmap
plt.figure(figsize=(12, 10))  # Adjust figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()'''
# Out:
# '# Calculate the correlation matrix\ncorrelation_matrix = df.corr()\n\n# Create the heatmap\nplt.figure(figsize=(12, 10))  # Adjust figure size as needed\nsns.heatmap(correlation_matrix, annot=True, cmap=\'coolwarm\', fmt=".2f")\nplt.title(\'Correlation Heatmap\')\nplt.show()'

# %% [markdown]
# # Model Building

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cap_shape                 2000 non-null   int64
#  1   cap_surface               2000 non-null   int64
#  2   cap_color                 2000 non-null   int64
#  3   bruises                   2000 non-null   int64
#  4   odor                      2000 non-null   int64
#  5   gill_attachment           2000 non-null   int64
#  6   gill_spacing              2000 non-null   int64
#  7   gill_size                 2000 non-null   int64
#  8   gill_color                2000 non-null   int64
#  9   stalk_shape               2000 non-null   int64
#  10  stalk_root                2000 non-null   int64
#  11  stalk_surface_above_ring  2000 non-null   int64
#  12  stalk_surface_below_ring  2000 non-null   int64
#  13  stalk_color_above_ring    2000 non-null   int64
# ...

# %%
#SVM
from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import cross_val_score

# %%
clf = SVC()
param_grid = [{'kernel':['rbf'],'gamma':[50,5,10,0.5],'C':[15,14,13,12,11,10,0.1,0.001] }]
gsv = GridSearchCV(clf,param_grid,cv=10)
gsv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid=[{'C': [15, 14, 13, 12, 11, 10, 0.1, 0.001],
#                           'gamma': [50, 5, 10, 0.5], 'kernel': ['rbf']}])

# %%
gsv.best_params_ , gsv.best_score_
# Out:
# ({'C': 15, 'gamma': 50, 'kernel': 'rbf'}, 0.8402985074626865)

# %%
clf = SVC(C= 15, gamma = 50)
clf.fit(X_train , y_train)
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(y_test, y_pred)
# Out:
# Accuracy = 87.27272727272727
# array([[126,  84],
#        [  0, 450]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75       210
#            1       0.84      1.00      0.91       450
#
#     accuracy                           0.87       660
#    macro avg       0.92      0.80      0.83       660
# weighted avg       0.89      0.87      0.86       660

# %%
clf = SVC(kernel= "linear")
clf.fit(X_train , y_train)
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(y_test, y_pred)
# Out:
# Accuracy = 68.18181818181817
# array([[  0, 210],
#        [  0, 450]])

# %%
clf = SVC(kernel= "poly")
clf.fit(X_train , y_train)
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(y_test, y_pred)
# Out:
# Accuracy = 72.57575757575758
# array([[ 45, 165],
#        [ 16, 434]])

# %%
clf = SVC(kernel= "sigmoid")
clf.fit(X_train , y_train)
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(y_test, y_pred)
# Out:
# Accuracy = 60.909090909090914
# array([[ 60, 150],
#        [108, 342]])

# %%
#  summary comarision
'''
# SVM Model Performance Summary

# The code trains and evaluates an SVM model on a mushroom dataset, exploring different kernels.

# Results:

# Kernel | Accuracy
# ------- | --------
# rbf     | [Insert rbf accuracy from the output]
# linear  | [Insert linear accuracy from the output]
# poly    | [Insert poly accuracy from the output]
# sigmoid | [Insert sigmoid accuracy from the output]

# Best Performing Kernel: [Insert the kernel with the highest accuracy]

# Additional Notes:

# - The 'rbf' kernel with C=15 and gamma=50 achieved the highest accuracy in the grid search.
# - Confusion matrices were generated for each kernel but not included in this summary.
# - Further analysis could involve feature importance, ROC curves, and other evaluation metrics.
# - The code uses Label Encoding for categorical features and MinMax scaling for numerical features.
'''
# Out:
# "\n# SVM Model Performance Summary\n\n# The code trains and evaluates an SVM model on a mushroom dataset, exploring different kernels.\n\n# Results:\n\n# Kernel | Accuracy\n# ------- | --------\n# rbf     | [Insert rbf accuracy from the output]\n# linear  | [Insert linear accuracy from the output]\n# poly    | [Insert poly accuracy from the output]\n# sigmoid | [Insert sigmoid accuracy from the output]\n\n# Best Performing Kernel: [Insert the kernel with the highest accuracy]\n\n# Additional Notes:\n\n# - The 'rbf' kernel with C=15 and gamma=50 achieved the highest accuracy in the grid search.\n# - Confusion matrices were generated for each kernel but not included in this summary.\n# - Further analysis could involve feature importance, ROC curves, and other evaluation metrics.\n# - The code uses Label Encoding for categorical features and MinMax scaling for numerical features.\n"

# %%
#3.	Discuss practical implications of SVM in real-world classification tasks.
'''
Text and Document Classification:
SVMs are widely used for tasks like spam detection, sentiment analysis, and document categorization due to their ability to handle high-dimensional data effectively.

Image and Pattern Recognition:
Applications include face detection, handwriting recognition, and object classification, where SVMs excel at distinguishing complex patterns.

Bioinformatics:
SVMs are used for protein structure classification, gene expression analysis, and disease diagnosis, particularly in cancer detection and genomic research.

Fraud Detection and Risk Assessment:
In finance, SVMs help classify fraudulent transactions and assess credit risk by identifying subtle patterns in transactional data.

Healthcare and Drug Discovery:
SVMs support medical diagnostics and drug interaction predictions, aiding in personalized medicine and research.
'''
# Out:
# '\nText and Document Classification:\nSVMs are widely used for tasks like spam detection, sentiment analysis, and document categorization due to their ability to handle high-dimensional data effectively.\n\nImage and Pattern Recognition:\nApplications include face detection, handwriting recognition, and object classification, where SVMs excel at distinguishing complex patterns.\n\nBioinformatics:\nSVMs are used for protein structure classification, gene expression analysis, and disease diagnosis, particularly in cancer detection and genomic research.\n\nFraud Detection and Risk Assessment:\nIn finance, SVMs help classify fraudulent transactions and assess credit risk by identifying subtle patterns in transactional data.\n\nHealthcare and Drug Discovery:\nSVMs support medical diagnostics and drug interaction predictions, aiding in personalized medicine and research.\n'
